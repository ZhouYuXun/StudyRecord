# %%
import cv2
import numpy as np

h1 = cv2.imread('h2.png', 1)

h2 = np.full(h1.shape, 254, np.uint8)

h3 = cv2.add(h1, h2)

h3 = cv2.cvtColor(h3, cv2.COLOR_BGR2GRAY)

ret, threshold = cv2.threshold(h3, 0, 255,  cv2.THRESH_OTSU)

cv2_imshow(threshold)
