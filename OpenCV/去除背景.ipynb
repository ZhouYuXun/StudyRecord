# %%
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow

# %%
# m1 = cv2.imread('1.jpg', 1)

# cv2_imshow(m1)

# %%
#圖像加法=增亮 超過等於255

# m3 = cv2.add(m1, (50, 50, 50, 0))

# cv2_imshow(m3)

# %%
#圖像減法=增暗 超過等於0

#m3 = cv2.subtract(m1, (50, 50, 50, 0))

# cv2_imshow(m3)

# %%
#圖像相減取絕對值=色差 減的剛剛好能夠區分相近顏色

# m2 = np.full(m1.shape, 255, np.uint8)

# m3 = cv2.absdiff(m1, m2)

# cv2_imshow(m3)

# %%
#圖像除法與乘法=急速增亮或暗 除與乘法搭配由於四捨五入後顏色減少

#m2 = np.full(m1.shape, 2, np.uint8)

#m3 = cv2.divide(m1, m2)

#m3 = cv2.multiply(m1, m2)

#各像素值在二進位表示下做 not 運算：

#m3 = cv2.bitwise_not(m1)

# %%
#圖像縮放

# m3 = cv2.resize(m1, (500,500))

#圖像翻轉 1 = 左右  0 = 上下  -1 = 左右上下

# m3 = cv2.flip(m1, 1)

#圖像旋轉 ((旋轉中心), 角度, 縮放比率)

# gr = cv2.getRotationMatrix2D((300, 400), 45, 1.5)

#輸出圖像大小

# m3 = cv2.warpAffine(m1, gr, (600, 600))

# 裁切複製貼上

# %%
# h1 = cv2.Canny(m1, 300, 200)

# cv2_imshow(h1)

# %%
# 平均值模糊法 馬賽克

# h1 = cv2.blur(m1, (10,10))

# cv2_imshow(h1)

# # 中值模糊法 遠看

# h1 = cv2.medianBlur(m1, 101)

# cv2_imshow(h1)

# %%
h1 = cv2.imread('h2.png', 1) 

h2 = np.full(h1.shape, 255, np.uint8)

h1 = cv2.subtract(h1, (255, 255, 254, 0)) # 字 0 0 1 背景 0 0 0

h1[:,:,2] = h1[:,:,2]*255 # 字 0 0 255 背景 0 0 0

# h1 = cv2.cvtColor(h1, cv2.COLOR_BGR2GRAY)

# h2 = np.full(h1.shape, 255, np.uint8)

# h1 = cv2.subtract(h1, h2)

# h1 = cv2.bitwise_not(h1)

# h2 = np.full(h1.shape, 255, np.uint8)

# h1 = cv2.multiply(h1, h2)

cv2_imshow(h1)
